# %%
from pathlib import Path
import os
import time
import random
import torch
import pickle

import numpy as np
import pandas as pd

from training import train_single
from data_helpers import make_loader
from models_transformer import SingleOutTransformerNet
from metrics import eval_single_metrics_test

# %%
OUTDIR = Path("./Results")
ATTNDIR = Path("./Results/attention_scores")
SHAPDIR = Path("./Results/shap_values/tables")
HISTDIR = Path("./Results/train_history")
METDIR = Path("./Results/test_metrics")
OUTDIR.mkdir(parents=True, exist_ok=True)
MODELSDIR = Path("./trained_models")
MODELSDIR.mkdir(parents=True, exist_ok=True)

# %%
SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

DEVICE = torch.device("cpu")
print("Device:", DEVICE)
# Out:
# Device: cpu

# %% [markdown]
# ### Load data

# %%
train_data = np.load("data_processed/train_data.npz")
val_data = np.load("data_processed/val_data.npz")
test_data = np.load("data_processed/test_data.npz")

X_train = train_data["x"]
y_train = train_data["age"]

X_val = val_data["x"]
y_val = val_data["age"]

X_test = test_data["x"]
y_test = test_data["age"]

# %%
train_data_s = np.load("data_processed/train_data_scaled.npz")
val_data_s = np.load("data_processed/val_data_scaled.npz")
test_data_s = np.load("data_processed/test_data_scaled.npz")

X_train_s = train_data_s["x"]
y_train_s = train_data_s["age"]

X_val_s = val_data_s["x"]
y_val_s = val_data_s["age"]

X_test_s = test_data_s["x"]
y_test_s = test_data_s["age"]

# %%
scalers = np.load("data_processed/scalers.npz")

x_mean, x_std = scalers["x_mean"], scalers["x_std"]
y_mean, y_std = scalers["age_mean"], scalers["age_std"]

# %% [markdown]
# #### Slice data

# %%
N_LAYERS = 11
scores_df_attn = pd.read_csv(ATTNDIR / f"{N_LAYERS}layers/attention_scores{N_LAYERS}layers.csv")
scores_df_shap = pd.read_csv(SHAPDIR / f"{N_LAYERS}layers/shap_scores{N_LAYERS}layers.csv")

top_k = 33
selector_attn = scores_df_attn["original_position"][:top_k].to_numpy()
selector_shap = scores_df_shap["original_position"][:top_k].to_numpy()

intersect = [value for value in selector_attn if value in selector_shap]
top_k_eff = len(intersect)
print(f"Number of features considered: {top_k_eff}")
sorted_selector = np.sort(intersect)

kept_features = scores_df_attn["feature"][intersect].values.tolist()
with open(f"data_processed/dataframes/{N_LAYERS}layers/input_cols_pruned_intersect{top_k_eff}.pkl", 
          "wb") as f:
    pickle.dump(kept_features, f)

X_train_sliced = X_train[:, sorted_selector]
X_val_sliced = X_val[:, sorted_selector]
X_test_sliced = X_test[:, sorted_selector]

X_train_s_sliced = X_train_s[:, sorted_selector]
X_val_s_sliced = X_val_s[:, sorted_selector]
X_test_s_sliced = X_test_s[:, sorted_selector]
# Out:
# Number of features considered: 26

# %% [markdown]
# #### Dataloaders

# %%
BATCH_SIZE = 128

train_loader = make_loader(X_train_s_sliced, y_train_s, BATCH_SIZE)
val_loader = make_loader(X_val_s_sliced, y_val_s, BATCH_SIZE)
test_loader = make_loader(X_test_s_sliced, y_test_s, BATCH_SIZE)

# %% [markdown]
# ### Models and training

# %%
EPOCHS = 150
# METRICS_EVERY = int(EPOCHS/8)
METRICS_EVERY = 1
LR = 1e-3
WD = 1e-5

# %%
IN_DIM = X_train_s_sliced.shape[1]

EMB_DIM = 64
NHEAD = 4
NUM_LAYERS = N_LAYERS
FF_DIM = 128
DROPOUT = 0.1

# %%
torch.manual_seed(SEED)    
model_single = SingleOutTransformerNet(IN_DIM, emb_dim=EMB_DIM, nhead=NHEAD, 
                                       num_layers=NUM_LAYERS, ff_dim=FF_DIM, 
                                       dropout=DROPOUT).to(DEVICE)    

loss = torch.nn.SmoothL1Loss()
optimizer = torch.optim.Adam(model_single.parameters(), lr=LR, weight_decay=WD)

hist_df = train_single(model_single, loss, optimizer, train_loader, val_loader, 
                       device=DEVICE, epochs=EPOCHS, metrics_every=METRICS_EVERY)

hist_df.to_csv(HISTDIR / f"{N_LAYERS}layers/train_history_{N_LAYERS}layers_intersect{top_k_eff}.csv", 
               index=False)
torch.save(model_single.state_dict(), 
           MODELSDIR / f"TR_model_{N_LAYERS}layers_intersect{top_k_eff}.pt")
# Out:
# ep=001 tr_loss=0.2975 | va_loss=0.2025 | tr R2=0.567 | va R2=0.550 | tr RMSE=0.658 | va RMSE=0.656 | tr MAE=0.512 | va MAE=0.513 | lr=1.00e-03 | bad_epochs=0
# ep=002 tr_loss=0.1973 | va_loss=0.1979 | tr R2=0.591 | va R2=0.559 | tr RMSE=0.639 | va RMSE=0.650 | tr MAE=0.496 | va MAE=0.502 | lr=1.00e-03 | bad_epochs=0
# ep=003 tr_loss=0.1942 | va_loss=0.1923 | tr R2=0.601 | va R2=0.572 | tr RMSE=0.632 | va RMSE=0.640 | tr MAE=0.494 | va MAE=0.495 | lr=1.00e-03 | bad_epochs=0
# ep=004 tr_loss=0.1888 | va_loss=0.1889 | tr R2=0.618 | va R2=0.582 | tr RMSE=0.618 | va RMSE=0.632 | tr MAE=0.478 | va MAE=0.493 | lr=1.00e-03 | bad_epochs=0
# ep=005 tr_loss=0.1875 | va_loss=0.2010 | tr R2=0.598 | va R2=0.555 | tr RMSE=0.634 | va RMSE=0.653 | tr MAE=0.496 | va MAE=0.514 | lr=1.00e-03 | bad_epochs=1
# ep=006 tr_loss=0.1802 | va_loss=0.1979 | tr R2=0.610 | va R2=0.558 | tr RMSE=0.625 | va RMSE=0.650 | tr MAE=0.488 | va MAE=0.502 | lr=1.00e-03 | bad_epochs=2
# ep=007 tr_loss=0.1789 | va_loss=0.1890 | tr R2=0.625 | va R2=0.582 | tr RMSE=0.612 | va RMSE=0.632 | tr MAE=0.484 | va MAE=0.492 | lr=1.00e-03 | bad_epochs=3
# ep=008 tr_loss=0.1788 | va_loss=0.1816 | tr R2=0.649 | va R2=0.597 | tr RMSE=0.592 | va RMSE=0.621 | tr MAE=0.462 | va MAE=0.482 | lr=1.00e-03 | bad_epochs=0
# ep=009 tr_loss=0.1749 | va_loss=0.1841 | tr R2=0.636 | va R2=0.595 | tr RMSE=0.604 | va RMSE=0.622 | tr MAE=0.471 | va MAE=0.483 | lr=1.00e-03 | bad_epochs=1
# ep=010 tr_loss=0.1750 | va_loss=0.1750 | tr R2=0.659 | va R2=0.617 | tr RMSE=0.584 | va RMSE=0.605 | tr MAE=0.456 | va MAE=0.475 | lr=1.00e-03 | bad_epochs=0
# ep=011 tr_loss=0.1718 | va_loss=0.1768 | tr R2=0.660 | va R2=0.610 | tr RMSE=0.583 | va RMSE=0.611 | tr MAE=0.456 | va MAE=0.476 | lr=1.00e-03 | bad_epochs=1
# ep=012 tr_loss=0.1718 | va_loss=0.1921 | tr R2=0.630 | va R2=0.573 | tr RMSE=0.609 | va RMSE=0.639 | tr MAE=0.476 | va MAE=0.500 | lr=1.00e-03 | bad_epochs=2
# ep=013 tr_loss=0.1717 | va_loss=0.1802 | tr R2=0.646 | va R2=0.606 | tr RMSE=0.595 | va RMSE=0.614 | tr MAE=0.470 | va MAE=0.485 | lr=1.00e-03 | bad_epochs=3
# ep=014 tr_loss=0.1706 | va_loss=0.1772 | tr R2=0.672 | va R2=0.610 | tr RMSE=0.573 | va RMSE=0.611 | tr MAE=0.445 | va MAE=0.476 | lr=1.00e-03 | bad_epochs=4
# ep=015 tr_loss=0.1668 | va_loss=0.1885 | tr R2=0.645 | va R2=0.583 | tr RMSE=0.596 | va RMSE=0.631 | tr MAE=0.458 | va MAE=0.491 | lr=1.00e-03 | bad_epochs=5
# ep=016 tr_loss=0.1667 | va_loss=0.1812 | tr R2=0.663 | va R2=0.601 | tr RMSE=0.581 | va RMSE=0.618 | tr MAE=0.454 | va MAE=0.486 | lr=1.00e-03 | bad_epochs=6
# ep=017 tr_loss=0.1651 | va_loss=0.1841 | tr R2=0.665 | va R2=0.591 | tr RMSE=0.579 | va RMSE=0.626 | tr MAE=0.446 | va MAE=0.486 | lr=1.00e-03 | bad_epochs=7
# ep=018 tr_loss=0.1655 | va_loss=0.1749 | tr R2=0.677 | va R2=0.613 | tr RMSE=0.568 | va RMSE=0.608 | tr MAE=0.441 | va MAE=0.473 | lr=1.00e-03 | bad_epochs=0
# ep=019 tr_loss=0.1684 | va_loss=0.1801 | tr R2=0.675 | va R2=0.601 | tr RMSE=0.570 | va RMSE=0.617 | tr MAE=0.442 | va MAE=0.477 | lr=1.00e-03 | bad_epochs=1
# ep=020 tr_loss=0.1631 | va_loss=0.1840 | tr R2=0.670 | va R2=0.592 | tr RMSE=0.575 | va RMSE=0.625 | tr MAE=0.444 | va MAE=0.484 | lr=1.00e-03 | bad_epochs=2
# ep=021 tr_loss=0.1627 | va_loss=0.1773 | tr R2=0.680 | va R2=0.609 | tr RMSE=0.565 | va RMSE=0.611 | tr MAE=0.439 | va MAE=0.477 | lr=1.00e-03 | bad_epochs=3
# ep=022 tr_loss=0.1607 | va_loss=0.1802 | tr R2=0.682 | va R2=0.602 | tr RMSE=0.564 | va RMSE=0.617 | tr MAE=0.443 | va MAE=0.485 | lr=1.00e-03 | bad_epochs=4
# ep=023 tr_loss=0.1621 | va_loss=0.1799 | tr R2=0.681 | va R2=0.602 | tr RMSE=0.565 | va RMSE=0.617 | tr MAE=0.437 | va MAE=0.476 | lr=1.00e-03 | bad_epochs=5
# ep=024 tr_loss=0.1620 | va_loss=0.1817 | tr R2=0.676 | va R2=0.600 | tr RMSE=0.569 | va RMSE=0.619 | tr MAE=0.446 | va MAE=0.485 | lr=1.00e-03 | bad_epochs=6
# ep=025 tr_loss=0.1603 | va_loss=0.1789 | tr R2=0.679 | va R2=0.605 | tr RMSE=0.566 | va RMSE=0.614 | tr MAE=0.441 | va MAE=0.478 | lr=1.00e-03 | bad_epochs=7
# ep=026 tr_loss=0.1608 | va_loss=0.1781 | tr R2=0.689 | va R2=0.606 | tr RMSE=0.558 | va RMSE=0.614 | tr MAE=0.436 | va MAE=0.476 | lr=1.00e-03 | bad_epochs=8
# ep=027 tr_loss=0.1583 | va_loss=0.1791 | tr R2=0.684 | va R2=0.605 | tr RMSE=0.562 | va RMSE=0.615 | tr MAE=0.436 | va MAE=0.480 | lr=1.00e-03 | bad_epochs=9
# ep=028 tr_loss=0.1608 | va_loss=0.1845 | tr R2=0.677 | va R2=0.591 | tr RMSE=0.569 | va RMSE=0.626 | tr MAE=0.443 | va MAE=0.488 | lr=1.00e-03 | bad_epochs=10
# ep=029 tr_loss=0.1574 | va_loss=0.1785 | tr R2=0.692 | va R2=0.604 | tr RMSE=0.555 | va RMSE=0.615 | tr MAE=0.437 | va MAE=0.478 | lr=1.00e-04 | bad_epochs=11
# ep=030 tr_loss=0.1482 | va_loss=0.1739 | tr R2=0.706 | va R2=0.614 | tr RMSE=0.542 | va RMSE=0.608 | tr MAE=0.421 | va MAE=0.469 | lr=1.00e-04 | bad_epochs=0
# ep=031 tr_loss=0.1459 | va_loss=0.1746 | tr R2=0.709 | va R2=0.613 | tr RMSE=0.539 | va RMSE=0.608 | tr MAE=0.419 | va MAE=0.471 | lr=1.00e-04 | bad_epochs=1
# ep=032 tr_loss=0.1453 | va_loss=0.1736 | tr R2=0.713 | va R2=0.616 | tr RMSE=0.536 | va RMSE=0.606 | tr MAE=0.417 | va MAE=0.470 | lr=1.00e-04 | bad_epochs=0
# ep=033 tr_loss=0.1438 | va_loss=0.1754 | tr R2=0.713 | va R2=0.611 | tr RMSE=0.536 | va RMSE=0.610 | tr MAE=0.416 | va MAE=0.472 | lr=1.00e-04 | bad_epochs=1
# ep=034 tr_loss=0.1437 | va_loss=0.1755 | tr R2=0.715 | va R2=0.611 | tr RMSE=0.534 | va RMSE=0.610 | tr MAE=0.414 | va MAE=0.472 | lr=1.00e-04 | bad_epochs=2
# ep=035 tr_loss=0.1426 | va_loss=0.1762 | tr R2=0.717 | va R2=0.609 | tr RMSE=0.532 | va RMSE=0.612 | tr MAE=0.414 | va MAE=0.473 | lr=1.00e-04 | bad_epochs=3
# ep=036 tr_loss=0.1423 | va_loss=0.1760 | tr R2=0.718 | va R2=0.610 | tr RMSE=0.531 | va RMSE=0.611 | tr MAE=0.413 | va MAE=0.474 | lr=1.00e-04 | bad_epochs=4
# ep=037 tr_loss=0.1429 | va_loss=0.1748 | tr R2=0.720 | va R2=0.612 | tr RMSE=0.529 | va RMSE=0.609 | tr MAE=0.412 | va MAE=0.472 | lr=1.00e-04 | bad_epochs=5
# ep=038 tr_loss=0.1422 | va_loss=0.1764 | tr R2=0.719 | va R2=0.608 | tr RMSE=0.530 | va RMSE=0.612 | tr MAE=0.411 | va MAE=0.473 | lr=1.00e-04 | bad_epochs=6
# ep=039 tr_loss=0.1422 | va_loss=0.1757 | tr R2=0.721 | va R2=0.610 | tr RMSE=0.528 | va RMSE=0.611 | tr MAE=0.411 | va MAE=0.473 | lr=1.00e-04 | bad_epochs=7
# ep=040 tr_loss=0.1421 | va_loss=0.1766 | tr R2=0.721 | va R2=0.607 | tr RMSE=0.528 | va RMSE=0.613 | tr MAE=0.410 | va MAE=0.473 | lr=1.00e-04 | bad_epochs=8
# ep=041 tr_loss=0.1413 | va_loss=0.1762 | tr R2=0.723 | va R2=0.609 | tr RMSE=0.526 | va RMSE=0.611 | tr MAE=0.410 | va MAE=0.472 | lr=1.00e-04 | bad_epochs=9
# ep=042 tr_loss=0.1406 | va_loss=0.1784 | tr R2=0.723 | va R2=0.603 | tr RMSE=0.526 | va RMSE=0.616 | tr MAE=0.408 | va MAE=0.475 | lr=1.00e-04 | bad_epochs=10
# ep=043 tr_loss=0.1413 | va_loss=0.1750 | tr R2=0.725 | va R2=0.612 | tr RMSE=0.524 | va RMSE=0.609 | tr MAE=0.407 | va MAE=0.471 | lr=1.00e-05 | bad_epochs=11
# ep=044 tr_loss=0.1392 | va_loss=0.1755 | tr R2=0.726 | va R2=0.611 | tr RMSE=0.524 | va RMSE=0.610 | tr MAE=0.406 | va MAE=0.472 | lr=1.00e-05 | bad_epochs=12
# ep=045 tr_loss=0.1386 | va_loss=0.1755 | tr R2=0.726 | va R2=0.611 | tr RMSE=0.523 | va RMSE=0.610 | tr MAE=0.406 | va MAE=0.472 | lr=1.00e-05 | bad_epochs=13
# ep=046 tr_loss=0.1387 | va_loss=0.1758 | tr R2=0.727 | va R2=0.610 | tr RMSE=0.523 | va RMSE=0.611 | tr MAE=0.406 | va MAE=0.472 | lr=1.00e-05 | bad_epochs=14
# ep=047 tr_loss=0.1388 | va_loss=0.1759 | tr R2=0.727 | va R2=0.610 | tr RMSE=0.523 | va RMSE=0.611 | tr MAE=0.406 | va MAE=0.472 | lr=1.00e-05 | bad_epochs=15
# Early stopping at epoch 47. Best epoch was 32 with val_loss=0.173602.
# best epoch: 32
# best val loss: 0.173602

# %%
total_time = np.sum(hist_df["time"].to_numpy())
print(f"Total training time: {total_time} sec.")
# Out:
# Total training time: 1307.9625236988068 sec.

# %%
m_te = eval_single_metrics_test(model_single, X_test_s_sliced, y_test, y_mean, y_std, DEVICE)

single_test_rows = []
single_test_rows.append(["age", m_te["R2"], m_te["RMSE"], m_te["MAE"]])

# %%
single_metrics_df = pd.DataFrame(
    single_test_rows,
    columns=["output", "R2", "RMSE", "MAE"]
)
single_metrics_path = METDIR / f"{N_LAYERS}layers/test_metrics_{N_LAYERS}layers_intersect{top_k_eff}.csv"
single_metrics_df.to_csv(single_metrics_path, index=False, float_format="%.6f")

# %%
single_metrics_df
# Out:
#   output        R2      RMSE       MAE
# 0    age  0.650843  8.058805  6.259209
