# %%
from pathlib import Path
import os
import time
import random
import torch

import numpy as np
import pandas as pd

from training import train_single
from data_helpers import make_loader
from models_transformer import SingleOutTransformerNet
from metrics import eval_single_metrics_test

import pickle

# %%
OUTDIR = Path("./Results")
OUTDIR.mkdir(parents=True, exist_ok=True)
MODELSDIR = Path("./trained_models")
MODELSDIR.mkdir(parents=True, exist_ok=True)

# %%
SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

DEVICE = torch.device("cpu")
print("Device:", DEVICE)
# Out:
# Device: cpu

# %% [markdown]
# ### Load data

# %%
train_data = np.load("data_processed/train_data.npz")
val_data = np.load("data_processed/val_data.npz")
test_data = np.load("data_processed/test_data.npz")

X_train = train_data["x"]
y_train = train_data["age"]

X_val = val_data["x"]
y_val = val_data["age"]

X_test = test_data["x"]
y_test = test_data["age"]

# %%
train_data_s = np.load("data_processed/train_data_scaled.npz")
val_data_s = np.load("data_processed/val_data_scaled.npz")
test_data_s = np.load("data_processed/test_data_scaled.npz")

X_train_s = train_data_s["x"]
y_train_s = train_data_s["age"]

X_val_s = val_data_s["x"]
y_val_s = val_data_s["age"]

X_test_s = test_data_s["x"]
y_test_s = test_data_s["age"]

# %%
scalers = np.load("data_processed/scalers.npz")

x_mean, x_std = scalers["x_mean"], scalers["x_std"]
y_mean, y_std = scalers["age_mean"], scalers["age_std"]

# %% [markdown]
# #### Slice data

# %%
N_LAYERS = 20
scores_df = pd.read_csv(f"Results/shap_values/tables/shap_scores{N_LAYERS}layers.csv")

top_k = 25
selector = scores_df["original_position"][:top_k].to_numpy()
sorted_selector = np.sort(selector)

kept_features = scores_df["feature"][selector].values.tolist()
with open(f"data_processed/dataframes/input_cols_pruned_shap{top_k}.pkl", "wb") as f:
    pickle.dump(kept_features, f)

X_train_sliced = X_train[:, sorted_selector]
X_val_sliced = X_val[:, sorted_selector]
X_test_sliced = X_test[:, sorted_selector]

X_train_s_sliced = X_train_s[:, sorted_selector]
X_val_s_sliced = X_val_s[:, sorted_selector]
X_test_s_sliced = X_test_s[:, sorted_selector]

# %% [markdown]
# #### Dataloaders

# %%
BATCH_SIZE = 128

train_loader = make_loader(X_train_s_sliced, y_train_s, BATCH_SIZE)
val_loader = make_loader(X_val_s_sliced, y_val_s, BATCH_SIZE)
test_loader = make_loader(X_test_s_sliced, y_test_s, BATCH_SIZE)

# %% [markdown]
# ### Models and training

# %%
EPOCHS = 150
# METRICS_EVERY = int(EPOCHS/8)
METRICS_EVERY = 1
LR = 1e-3
WD = 1e-5

# %%
IN_DIM = X_train_s_sliced.shape[1]

EMB_DIM = 64
NHEAD = 4
NUM_LAYERS = N_LAYERS
FF_DIM = 128
DROPOUT = 0.1

# %%
torch.manual_seed(SEED)    
model_single = SingleOutTransformerNet(IN_DIM, emb_dim=EMB_DIM, nhead=NHEAD, 
                                       num_layers=NUM_LAYERS, ff_dim=FF_DIM, 
                                       dropout=DROPOUT).to(DEVICE)    

loss = torch.nn.SmoothL1Loss()
optimizer = torch.optim.Adam(model_single.parameters(), lr=LR, weight_decay=WD)

hist_df = train_single(model_single, loss, optimizer, train_loader, val_loader, 
                       device=DEVICE, epochs=EPOCHS, metrics_every=METRICS_EVERY)

hist_df.to_csv(f"Results/train_history/train_history_{NUM_LAYERS}layers_shap{top_k}.csv", 
               index=False)
torch.save(model_single.state_dict(), MODELSDIR / f"TR_model_{NUM_LAYERS}layers_shap{top_k}.pt")
# Out:
# ep=001 tr_loss=0.2859 | va_loss=0.2319 | tr R2=0.510 | va R2=0.479 | tr RMSE=0.700 | va RMSE=0.706 | tr MAE=0.552 | va MAE=0.550 | lr=1.00e-03 | bad_epochs=0
# ep=002 tr_loss=0.1981 | va_loss=0.1845 | tr R2=0.617 | va R2=0.592 | tr RMSE=0.619 | va RMSE=0.625 | tr MAE=0.486 | va MAE=0.490 | lr=1.00e-03 | bad_epochs=0
# ep=003 tr_loss=0.1912 | va_loss=0.1873 | tr R2=0.617 | va R2=0.582 | tr RMSE=0.619 | va RMSE=0.632 | tr MAE=0.486 | va MAE=0.496 | lr=1.00e-03 | bad_epochs=1
# ep=004 tr_loss=0.1884 | va_loss=0.1816 | tr R2=0.628 | va R2=0.598 | tr RMSE=0.610 | va RMSE=0.620 | tr MAE=0.473 | va MAE=0.480 | lr=1.00e-03 | bad_epochs=0
# ep=005 tr_loss=0.1875 | va_loss=0.1943 | tr R2=0.603 | va R2=0.566 | tr RMSE=0.630 | va RMSE=0.645 | tr MAE=0.491 | va MAE=0.504 | lr=1.00e-03 | bad_epochs=1
# ep=006 tr_loss=0.1789 | va_loss=0.2055 | tr R2=0.580 | va R2=0.539 | tr RMSE=0.648 | va RMSE=0.664 | tr MAE=0.512 | va MAE=0.511 | lr=1.00e-03 | bad_epochs=2
# ep=007 tr_loss=0.1807 | va_loss=0.2048 | tr R2=0.580 | va R2=0.544 | tr RMSE=0.648 | va RMSE=0.661 | tr MAE=0.513 | va MAE=0.526 | lr=1.00e-03 | bad_epochs=3
# ep=008 tr_loss=0.1751 | va_loss=0.1759 | tr R2=0.647 | va R2=0.612 | tr RMSE=0.594 | va RMSE=0.609 | tr MAE=0.460 | va MAE=0.478 | lr=1.00e-03 | bad_epochs=0
# ep=009 tr_loss=0.1763 | va_loss=0.1736 | tr R2=0.653 | va R2=0.619 | tr RMSE=0.589 | va RMSE=0.604 | tr MAE=0.461 | va MAE=0.476 | lr=1.00e-03 | bad_epochs=0
# ep=010 tr_loss=0.1694 | va_loss=0.1744 | tr R2=0.647 | va R2=0.615 | tr RMSE=0.594 | va RMSE=0.607 | tr MAE=0.461 | va MAE=0.474 | lr=1.00e-03 | bad_epochs=1
# ep=011 tr_loss=0.1695 | va_loss=0.1834 | tr R2=0.636 | va R2=0.591 | tr RMSE=0.603 | va RMSE=0.625 | tr MAE=0.469 | va MAE=0.478 | lr=1.00e-03 | bad_epochs=2
# ep=012 tr_loss=0.1709 | va_loss=0.1798 | tr R2=0.643 | va R2=0.603 | tr RMSE=0.598 | va RMSE=0.616 | tr MAE=0.465 | va MAE=0.483 | lr=1.00e-03 | bad_epochs=3
# ep=013 tr_loss=0.1701 | va_loss=0.1744 | tr R2=0.654 | va R2=0.618 | tr RMSE=0.588 | va RMSE=0.604 | tr MAE=0.465 | va MAE=0.475 | lr=1.00e-03 | bad_epochs=4
# ep=014 tr_loss=0.1678 | va_loss=0.1711 | tr R2=0.666 | va R2=0.623 | tr RMSE=0.578 | va RMSE=0.600 | tr MAE=0.447 | va MAE=0.466 | lr=1.00e-03 | bad_epochs=0
# ep=015 tr_loss=0.1653 | va_loss=0.1684 | tr R2=0.670 | va R2=0.632 | tr RMSE=0.575 | va RMSE=0.593 | tr MAE=0.452 | va MAE=0.469 | lr=1.00e-03 | bad_epochs=0
# ep=016 tr_loss=0.1663 | va_loss=0.1681 | tr R2=0.673 | va R2=0.631 | tr RMSE=0.572 | va RMSE=0.594 | tr MAE=0.446 | va MAE=0.462 | lr=1.00e-03 | bad_epochs=0
# ep=017 tr_loss=0.1650 | va_loss=0.1705 | tr R2=0.672 | va R2=0.625 | tr RMSE=0.573 | va RMSE=0.599 | tr MAE=0.446 | va MAE=0.468 | lr=1.00e-03 | bad_epochs=1
# ep=018 tr_loss=0.1634 | va_loss=0.1758 | tr R2=0.661 | va R2=0.611 | tr RMSE=0.582 | va RMSE=0.610 | tr MAE=0.451 | va MAE=0.475 | lr=1.00e-03 | bad_epochs=2
# ep=019 tr_loss=0.1627 | va_loss=0.1714 | tr R2=0.677 | va R2=0.624 | tr RMSE=0.569 | va RMSE=0.600 | tr MAE=0.445 | va MAE=0.471 | lr=1.00e-03 | bad_epochs=3
# ep=020 tr_loss=0.1634 | va_loss=0.1829 | tr R2=0.657 | va R2=0.596 | tr RMSE=0.586 | va RMSE=0.621 | tr MAE=0.461 | va MAE=0.484 | lr=1.00e-03 | bad_epochs=4
# ep=021 tr_loss=0.1608 | va_loss=0.2048 | tr R2=0.605 | va R2=0.547 | tr RMSE=0.629 | va RMSE=0.658 | tr MAE=0.498 | va MAE=0.515 | lr=1.00e-03 | bad_epochs=5
# ep=022 tr_loss=0.1625 | va_loss=0.1723 | tr R2=0.675 | va R2=0.621 | tr RMSE=0.570 | va RMSE=0.602 | tr MAE=0.447 | va MAE=0.469 | lr=1.00e-03 | bad_epochs=6
# ep=023 tr_loss=0.1607 | va_loss=0.1727 | tr R2=0.679 | va R2=0.619 | tr RMSE=0.567 | va RMSE=0.604 | tr MAE=0.441 | va MAE=0.470 | lr=1.00e-03 | bad_epochs=7
# ep=024 tr_loss=0.1578 | va_loss=0.1668 | tr R2=0.693 | va R2=0.635 | tr RMSE=0.554 | va RMSE=0.591 | tr MAE=0.435 | va MAE=0.464 | lr=1.00e-03 | bad_epochs=0
# ep=025 tr_loss=0.1595 | va_loss=0.1774 | tr R2=0.677 | va R2=0.608 | tr RMSE=0.568 | va RMSE=0.613 | tr MAE=0.442 | va MAE=0.472 | lr=1.00e-03 | bad_epochs=1
# ep=026 tr_loss=0.1612 | va_loss=0.1729 | tr R2=0.687 | va R2=0.618 | tr RMSE=0.560 | va RMSE=0.605 | tr MAE=0.441 | va MAE=0.472 | lr=1.00e-03 | bad_epochs=2
# ep=027 tr_loss=0.1571 | va_loss=0.1739 | tr R2=0.691 | va R2=0.616 | tr RMSE=0.556 | va RMSE=0.606 | tr MAE=0.431 | va MAE=0.469 | lr=1.00e-03 | bad_epochs=3
# ep=028 tr_loss=0.1571 | va_loss=0.1700 | tr R2=0.703 | va R2=0.624 | tr RMSE=0.545 | va RMSE=0.600 | tr MAE=0.424 | va MAE=0.464 | lr=1.00e-03 | bad_epochs=4
# ep=029 tr_loss=0.1545 | va_loss=0.1719 | tr R2=0.693 | va R2=0.621 | tr RMSE=0.554 | va RMSE=0.602 | tr MAE=0.432 | va MAE=0.468 | lr=1.00e-03 | bad_epochs=5
# ep=030 tr_loss=0.1572 | va_loss=0.1733 | tr R2=0.695 | va R2=0.617 | tr RMSE=0.552 | va RMSE=0.606 | tr MAE=0.429 | va MAE=0.467 | lr=1.00e-03 | bad_epochs=6
# ep=031 tr_loss=0.1579 | va_loss=0.1686 | tr R2=0.703 | va R2=0.630 | tr RMSE=0.545 | va RMSE=0.595 | tr MAE=0.426 | va MAE=0.467 | lr=1.00e-03 | bad_epochs=7
# ep=032 tr_loss=0.1527 | va_loss=0.1758 | tr R2=0.692 | va R2=0.612 | tr RMSE=0.555 | va RMSE=0.609 | tr MAE=0.432 | va MAE=0.471 | lr=1.00e-03 | bad_epochs=8
# ep=033 tr_loss=0.1521 | va_loss=0.1711 | tr R2=0.708 | va R2=0.620 | tr RMSE=0.541 | va RMSE=0.603 | tr MAE=0.423 | va MAE=0.466 | lr=1.00e-03 | bad_epochs=9
# ep=034 tr_loss=0.1536 | va_loss=0.1734 | tr R2=0.707 | va R2=0.615 | tr RMSE=0.541 | va RMSE=0.607 | tr MAE=0.419 | va MAE=0.465 | lr=1.00e-03 | bad_epochs=10
# ep=035 tr_loss=0.1493 | va_loss=0.1713 | tr R2=0.711 | va R2=0.621 | tr RMSE=0.538 | va RMSE=0.602 | tr MAE=0.419 | va MAE=0.466 | lr=1.00e-04 | bad_epochs=11
# ep=036 tr_loss=0.1420 | va_loss=0.1683 | tr R2=0.724 | va R2=0.628 | tr RMSE=0.526 | va RMSE=0.596 | tr MAE=0.407 | va MAE=0.460 | lr=1.00e-04 | bad_epochs=12
# ep=037 tr_loss=0.1396 | va_loss=0.1689 | tr R2=0.727 | va R2=0.626 | tr RMSE=0.522 | va RMSE=0.598 | tr MAE=0.405 | va MAE=0.460 | lr=1.00e-04 | bad_epochs=13
# ep=038 tr_loss=0.1383 | va_loss=0.1693 | tr R2=0.729 | va R2=0.625 | tr RMSE=0.521 | va RMSE=0.599 | tr MAE=0.405 | va MAE=0.461 | lr=1.00e-04 | bad_epochs=14
# ep=039 tr_loss=0.1377 | va_loss=0.1702 | tr R2=0.730 | va R2=0.623 | tr RMSE=0.520 | va RMSE=0.600 | tr MAE=0.403 | va MAE=0.460 | lr=1.00e-04 | bad_epochs=15
# Early stopping at epoch 39. Best epoch was 24 with val_loss=0.166802.
# best epoch: 24
# best val loss: 0.166802

# %%
total_time = np.sum(hist_df["time"].to_numpy())
print(f"Total training time: {total_time} sec.")
# Out:
# Total training time: 1992.9714450836182 sec.

# %%
m_te = eval_single_metrics_test(model_single, X_test_s_sliced, y_test, y_mean, y_std, DEVICE)

single_test_rows = []
single_test_rows.append(["age", m_te["R2"], m_te["RMSE"], m_te["MAE"]])

# %%
single_metrics_df = pd.DataFrame(
    single_test_rows,
    columns=["output", "R2", "RMSE", "MAE"]
)
single_metrics_path = f"Results/test_metrics/test_metrics_{NUM_LAYERS}layers_shap{top_k}.csv"
single_metrics_df.to_csv(single_metrics_path, index=False, float_format="%.6f")

# %%
single_metrics_df
# Out:
#   output        R2      RMSE       MAE
# 0    age  0.668419  7.853343  6.179348
